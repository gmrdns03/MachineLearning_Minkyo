# %% [markdown]
# # 5.1 극한과 미분

# %% [markdown]
# ## 514 접선그리기

# %%
# 리스트 5.1

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

def my_func(x) :
    return 3*x**2 + 4*x -5

def my_func_dif(x) :
    return 6*x + 4

x = np.linspace(-3, 3)
y = my_func(x)

a = 1
y_t = my_func_dif(a)*x +my_func(a) - my_func_dif(a)*a
# x=1일 때의 접선. 접선 식을 사용

plt.plot(x, y, label='y')
plt.plot(x, y_t, label='y_t')
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %%
# 리스트 5.2
import numpy as np
import matplotlib.pyplot as plt

def my_func(x) :
    return -2*x**2 +x+3

def my_func_dif(x) :
    return -4*x +1

x = np.linspace(-3, 3)
y = my_func(x)

a = 1
y_t = my_func_dif(a)*x +my_func(a) - my_func_dif(a)*a
# x=1일 때의 접선. 접선 식을 사용

plt.plot(x, y, label='y')
plt.plot(x, y_t, label='y_t')
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %% [markdown]
# # 5.2 연쇄법칙

# %% [markdown]
# ## 521 합성함수
# 합성함수란 여러개 함수의 합성으로 표현되는 함수

# %% [markdown]
# ## 522 연쇄법칙
# 합성함수의 미분은 구성하는 각 함수의 동함수의 곱으로 나타낼 수 있다.
#
# 이를 연쇄법칙이라 한다.

# %% [markdown]
# ## 523 연쇄법칙의 증명

# %% [markdown]
# # 5.3 편미분

# %% [markdown]
# ## 편미분
# 여러개의 변수를 가진 함수에 대해 하나의 변수만으로 인한 미분을 편미분이라 한다.
#
# 편미분에 의해 구한함수를 편도함수라 한다.

# %% [markdown]
# # 5.4 전미분

# %% [markdown]
# # 5.5 다변수 합성합수의 연쇄법칙

# %% [markdown]
# # 5.6 네이피어수와 자연대수

# %% [markdown]
# ## 561 네이피어수
# 네이피어수 e는 수학적으로 원주율 파이처럼 무한으로 자리수가 이어지는 소수입니다.

# %% [markdown]
# ## 562 네이피어수의 구현
# exp() 함수

# %%
# 리스트 5.4 네이피어수를 표시한다.
import numpy as np

print(np.e)
print(np.exp(1)) # e의 1제곱
# Out:
# 2.718281828459045
# 2.718281828459045

# %%
# 리스트 5.5 네이피어수의 거듭제곱을 그래프로 한다.
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2,2)
y=np.exp(x) # 네이피어수의 거듭제곱

plt.plot(x, y)

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %% [markdown]
# ## 563 자연대수
# 자연대수는 e를 몇 제곱하면 x가 되는지를 나타낸다.

# %% [markdown]
# ## 564 자연대수와 도함수

# %% [markdown]
# ## 565 자연대수의 구현
# 자연대수는 numpy의 log()함수를 사용하여 구현할 수 있습니다.

# %%
# 리스트 5.6 log()함수를 사용하여 구현할 수 있습니다.
import numpy as np

print(np.log(np.e)) # 네이피어의 자연대수
print(np.log(np.exp(2))) # 네이피어수의 2제곱 자연대수
print(np.log(np.exp(12))) # 네이피어수의 12제곱 자연대수
# Out:
# 1.0
# 2.0
# 12.0

# %%
# 리스트 5.7 자연대수를 그래프로 한다.
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.01, 2)  # x는 0으로 할 수 없다.
y = np.log(x)  # 자연대수

plt.plot(x, y)

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %% [markdown]
# ## 566 시그모이드 함수
# 뉴럴네트워크에서는 시그모이드 함수라고 하는 네이피어수를 이용한 함수가 자주 사용된다.
#
# 시그모이드 함수는 x값이 작아지면 0에 가까워지고, x의 값이 커지면 1에 가까워진다.
# 도함수는 x가 0일 때 최댓값인 0.25를 취하고, 0으로부터 멀어지면 도함수는 0에 가까워진다.
#
# 시그모이드 함수에 의해 입력을 0과 1사이의 연속적인 출력으로 변환할 수 있다.
#
# 이 특성은 인공적인 신경세포의 흥분 정도를 나타내는 활성화 함수로서 시그모이드 함수가 사용된다.
#
# 또한, 시그모이드 함수의 도함수는 뉴럴 네트워크를 최적화하는 백프로퍼게이션 알고리즘에 사용된다.

# %%
# 리스트5.8 시그모이드 함수와 그 도함수의 그래프
import numpy as np
import matplotlib.pyplot as plt

def sigmoid_function(x) :  # 시그모이드 함수
    return 1/(1+np.exp(-x))

def grad_sigmoid(x) : # 시그모이드 함수의 도함수
    y = sigmoid_function(x)
    return (1-y)*y

x = np.linspace(-5,5)
y = sigmoid_function(x)
y_grad = grad_sigmoid(x)

plt.plot(x,y,label='y')
plt.plot(x, y_grad, label='y_grad')
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %% [markdown]
# # 5.7 최급강하법
# 미분에 의해 구한 기울기르 바탕으로 함수의 최솟값을 구한다.
#
# 인공지능에서 학습을 위한 알고리즘에 자주 이용됨

# %% [markdown]
# ## 571 최급 강하법
# ### 경사법
# 경사법은 함수의 미분값(기울기)을 바탕으로 최솟값 등을 탐색할 때 쓰는 알고리즘이다.
#
# 최급 강하법은 경사법의 일종
#
# 가장 급한 방향으로 강하하도록 해서 최솟값을 탐색할 수 있다.
#
# 최급 강하법으로 구할 수 있는 최솟값은 엄밀한 최솟값은 아니다. 그러나 현실의 문제를 다룰 때는 함수의 형상조차 알 수 없는 것이 많으므로 최급강하법으로 최솟값을 조금씩 탐색하는 접근이 유효하다.

# %%
# 리스트 5.11 최급강하법으로 함수의 최솟값을 구한다.
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

def my_func(x) :  # 최솟값을 구하는 함수
    return x**2 - 2*x

def grad_func(x) :  # 도함수
    return 2*x - 2 

eta = 0.1  # 학습계수
x = 4.0  # x에 초깃값을 설정
record_x = []  # x의 기록
record_y = []  # y의 기록

for i in range(20) :  # 20회 x를 갱신한다.
    y = my_func(x)
    record_x.append(x)
    record_y.append(y)
    x -= eta * grad_func(x) # 식 1
    
x_f = np.linspace(-2, 4)
y_f = my_func(x_f)

plt.plot(x_f ,y_f , linestyle='dashed')  # 함수를 점선으로 표시
plt.plot(record_x, record_y)  # x와 y의 기록을 표시

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %% [markdown]
# ## 국소적인 최솟값
# 최솟값에는 "전체의 최솟값"과 "국소적인 최솟값"이 있다.
#
# 인공지능 함수의 형상은 복잡한 것이 많아서 간혹 국소적인 최솟값에 걸려서 전체의 최솟값을 구하지 못하는 경우가 있다.
#
# 리스트 5.12의 코드에서 x의 초깃값을 1.6으로 했는데, 이 경우 오른쪽의 국소적인 최솟값에 트랩되어 빠져나올 수 없다.
#
# 초깃값 설정에 랜덤성을 도입하거나 초기에 적절하게 설정하면 이 문제를 해결할 수 있다.

# %%
# 리스트 5.12 국소적인 최솟값으로의 트랩
import numpy as np
import matplotlib.pyplot as plt

def my_func(x) :  # 최솟값을 구하는 함수
    return x**4 + 2*x**3 - 3*x**2 - 2*x

def grad_func(x) :  # 도함수
    return 4*x**3 + 6*x**2 - 6*x -2 

eta = 0.01  # 학습계수
x = 1.6  # x에 초깃값을 설정
record_x = []  # x의 기록
record_y = []  # y의 기록

for i in range(20) :  # 20회 x를 갱신한다.
    y = my_func(x)
    record_x.append(x)
    record_y.append(y)
    x -= eta * grad_func(x) # 식 1
    
x_f = np.linspace(-2.8, 1.6)
y_f = my_func(x_f)

plt.plot(x_f ,y_f , linestyle='dashed')  # 함수를 점선으로 표시
plt.plot(record_x, record_y)  # x와 y의 기록을 표시

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()
